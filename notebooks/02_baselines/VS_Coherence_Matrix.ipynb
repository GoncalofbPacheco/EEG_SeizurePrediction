# %% [markdown]
# # Main vs Coherence Matrix (CNN)
#
# Broadband spectral coherence matrix (18×18) fed to same CNN vs GC-CNN.

# %%
# --- portable repo bootstrap (added for public release; locates the repo root) ---
import sys as _sys, pathlib as _pl
REPO = _pl.Path.cwd()
while not (REPO / 'src' / 'config.py').exists() and REPO != REPO.parent:
    REPO = REPO.parent
_sys.path.insert(0, str(REPO / 'src'))
from pathlib import Path
CODE_DIR = str(REPO); CODE = REPO; CODEV2 = REPO; PROJECT_DIR = REPO
# --------------------------------------------------------------------------------

import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# [path set by bootstrap] CODE_DIR = r"<repo>/Code"
sys.path.insert(0, CODE_DIR)

from config import (
    DATA_ROOT, CANONICAL_CHANNELS, N_CHANNELS, FS,
    WINDOW_SEC, STEP_SEC, PREICTAL_SEC, SPH_SEC,
    POSTICTAL_EXCL_SEC, EXCLUDED_PATIENTS, RANDOM_SEED, RESULTS_DIR
)
from summary_parser import parse_all_summaries
from data_loader    import load_edf
from preprocessing  import bandpass_filter, segment_signal, label_windows
from metrics        import evaluate_predictions
np.random.seed(RANDOM_SEED)
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from scipy.signal import coherence
from sklearn.model_selection import train_test_split
torch.manual_seed(RANDOM_SEED)
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {DEVICE}')
# Out:
# Device: cpu

# %%
# Cell 1 — Parse
all_seizures = parse_all_summaries(DATA_ROOT)
print(f'Parsed {len(all_seizures)} patient entries.')
# Out:
# [INFO] chb01: 7 seizure-containing files, 7 total seizures
# [INFO] chb02: 3 seizure-containing files, 3 total seizures
# [INFO] chb03: 7 seizure-containing files, 7 total seizures
# [INFO] chb04: 3 seizure-containing files, 4 total seizures
# [INFO] chb05: 5 seizure-containing files, 5 total seizures
# [INFO] chb06: 7 seizure-containing files, 10 total seizures
# [INFO] chb07: 3 seizure-containing files, 3 total seizures
# [INFO] chb08: 5 seizure-containing files, 5 total seizures
# [INFO] chb09: 3 seizure-containing files, 4 total seizures
# [INFO] chb10: 7 seizure-containing files, 7 total seizures
# [INFO] chb11: 3 seizure-containing files, 3 total seizures
# [INFO] chb12: 13 seizure-containing files, 40 total seizures
# [INFO] chb13: 8 seizure-containing files, 12 total seizures
# [INFO] chb14: 7 seizure-containing files, 8 total seizures
# [INFO] chb15: 14 seizure-containing files, 20 total seizures
# [INFO] chb16: 6 seizure-containing files, 10 total seizures
# [INFO] chb17: 3 seizure-containing files, 3 total seizures
# [INFO] chb18: 6 seizure-containing files, 6 total seizures
# [INFO] chb19: 3 seizure-containing files, 3 total seizures
# [INFO] chb20: 6 seizure-containing files, 8 total seizures
# [INFO] chb21: 4 seizure-containing files, 4 total seizures
# [INFO] chb22: 3 seizure-containing files, 3 total seizures
# [INFO] chb23: 3 seizure-containing files, 7 total seizures
# [INFO] chb24: 12 seizure-containing files, 16 total seizures
# Parsed 24 patient entries.

# %%
# Cell 2 — Coherence matrix extraction
def coherence_matrix(window, fs):
    """
    Compute broadband mean coherence between all channel pairs.
    window: (n_channels, n_samples)
    Returns: (n_channels, n_channels) symmetric matrix, diagonal=1
    """
    n_ch = window.shape[0]
    mat  = np.eye(n_ch, dtype=np.float32)
    for i in range(n_ch):
        for j in range(i+1, n_ch):
            f, Cxy = coherence(window[i], window[j], fs=fs, nperseg=min(256, window.shape[1]))
            c = float(Cxy.mean())
            mat[i, j] = c
            mat[j, i] = c
    return mat

coh_patient_data = {}
patients = sorted([p for p in os.listdir(DATA_ROOT)
                   if os.path.isdir(os.path.join(DATA_ROOT, p))
                   and p.startswith('chb') and p not in EXCLUDED_PATIENTS])

for patient_id in patients:
    file_seizure_map = all_seizures.get(patient_id, {})
    if not file_seizure_map: continue
    print(f'\n{"─"*55}\nPatient: {patient_id}')
    all_X, all_y = [], []
    for filename in sorted(file_seizure_map):
        seizures = file_seizure_map[filename]
        if not seizures: continue
        edf_path = os.path.join(DATA_ROOT, patient_id, filename)
        if not os.path.exists(edf_path): continue
        try:
            signal, fs = load_edf(edf_path)
        except Exception: continue
        filtered  = bandpass_filter(signal)
        windows   = segment_signal(filtered)
        n_samples = filtered.shape[1]
        labels    = label_windows(n_samples, seizures)
        valid = labels != -1; windows = windows[valid]; labels = labels[valid]
        if (labels == 1).sum() == 0: continue
        matrices = np.array([coherence_matrix(w, fs) for w in windows])
        all_X.append(matrices); all_y.append(labels)
        print(f'  [OK] {filename}  pre={(labels==1).sum()}  int={(labels==0).sum()}')
    if not all_X: continue
    X = np.concatenate(all_X); y = np.concatenate(all_y)
    coh_patient_data[patient_id] = (X, y)
    print(f'  Total: {len(y)} windows')

patient_ids = sorted(coh_patient_data.keys())
print(f'\nCoherence data ready. Patients: {len(coh_patient_data)}')
# Out:
# ───────────────────────────────────────────────────────
# Patient: chb01
#   [OK] chb01_03.edf  pre=148  int=146
#     [LABEL] Seizure at 1467s: preictal window out of bounds (would start at -333s) — skipping preictal label.
#     [LABEL] Seizure at 1732s: preictal window out of bounds (would start at -68s) — skipping preictal label.
#     [LABEL] Seizure at 1015s: preictal window out of bounds (would start at -785s) — skipping preictal label.
#     [LABEL] Seizure at 1720s: preictal window out of bounds (would start at -80s) — skipping preictal label.
#     [LABEL] Seizure at 327s: preictal window out of bounds (would start at -1473s) — skipping preictal label.
#   [OK] chb01_26.edf  pre=148  int=33
#   Total: 475 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb02
#   [OK] chb02_16+.edf  pre=148  int=144
#     [LABEL] Seizure at 130s: preictal window out of bounds (would start at -1670s) — skipping preictal label.
#   [OK] chb02_19.edf  pre=148  int=183
#   Total: 623 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb03
#     [LABEL] Seizure at 362s: preictal window out of bounds (would start at -1438s) — skipping preictal label.
#     [LABEL] Seizure at 731s: preictal window out of bounds (would start at -1069s) — skipping preictal label.
#     [LABEL] Seizure at 432s: preictal window out of bounds (would start at -1368s) — skipping preictal label.
#   [OK] chb03_04.edf  pre=148  int=63
#   [OK] chb03_34.edf  pre=148  int=45
#   [OK] chb03_35.edf  pre=148  int=106
#     [LABEL] Seizure at 1725s: preictal window out of bounds (would start at -75s) — skipping preictal label.
#   Total: 658 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb04
#   [OK] chb04_05.edf  pre=148  int=627
#   [OK] chb04_08.edf  pre=148  int=1094
#     [LABEL] Seizure at 1679s: preictal window out of bounds (would start at -121s) — skipping preictal label.
#   Total: 2017 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb05
#     [LABEL] Seizure at 417s: preictal window out of bounds (would start at -1383s) — skipping preictal label.
#     [LABEL] Seizure at 1086s: preictal window out of bounds (would start at -714s) — skipping preictal label.
#   [OK] chb05_16.edf  pre=148  int=78
#   [OK] chb05_17.edf  pre=148  int=92
#   [OK] chb05_22.edf  pre=148  int=81
#   Total: 695 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb06
#     [LABEL] Seizure at 1724s: preictal window out of bounds (would start at -76s) — skipping preictal label.
#   [OK] chb06_01.edf  pre=296  int=681
#     [LABEL] Seizure at 327s: preictal window out of bounds (would start at -1473s) — skipping preictal label.
#   [OK] chb06_04.edf  pre=148  int=805
#   [OK] chb06_09.edf  pre=149  int=1105
#   [OK] chb06_10.edf  pre=148  int=1104
#     [LABEL] Seizure at 506s: preictal window out of bounds (would start at -1294s) — skipping preictal label.
#   [OK] chb06_18.edf  pre=148  int=626
#   [OK] chb06_24.edf  pre=148  int=1103
#   Total: 6461 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb07
#   [OK] chb07_12.edf  pre=149  int=1098
#   [OK] chb07_13.edf  pre=148  int=175
#   [OK] chb07_19.edf  pre=148  int=1215
#   Total: 2933 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb08
#   [OK] chb08_02.edf  pre=149  int=115
#   [OK] chb08_05.edf  pre=148  int=132
#   [OK] chb08_11.edf  pre=148  int=145
#   [OK] chb08_13.edf  pre=148  int=88
#   [OK] chb08_21.edf  pre=148  int=55
#   Total: 1276 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb09
#   [OK] chb09_06.edf  pre=148  int=1098
#   [OK] chb09_08.edf  pre=296  int=757
#   [OK] chb09_19.edf  pre=148  int=376
#   Total: 2823 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb10
#   [OK] chb10_12.edf  pre=148  int=478
#   [OK] chb10_20.edf  pre=148  int=535
#   [OK] chb10_27.edf  pre=148  int=380
#   [OK] chb10_30.edf  pre=148  int=381
#   [OK] chb10_31.edf  pre=148  int=380
#   [OK] chb10_38.edf  pre=148  int=376
#     [LABEL] Seizure at 1383s: preictal window out of bounds (would start at -417s) — skipping preictal label.
#   Total: 3418 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb13
#   [OK] chb13_19.edf  pre=148  int=54
#     [LABEL] Seizure at 934s: preictal window out of bounds (would start at -866s) — skipping preictal label.
#     [LABEL] Seizure at 142s: preictal window out of bounds (would start at -1658s) — skipping preictal label.
#     [LABEL] Seizure at 530s: preictal window out of bounds (would start at -1270s) — skipping preictal label.
#     [LABEL] Seizure at 458s: preictal window out of bounds (would start at -1342s) — skipping preictal label.
#   [OK] chb13_58.edf  pre=148  int=94
#   [OK] chb13_59.edf  pre=148  int=180
#     [LABEL] Seizure at 638s: preictal window out of bounds (would start at -1162s) — skipping preictal label.
#     [LABEL] Seizure at 851s: preictal window out of bounds (would start at -949s) — skipping preictal label.
#     [LABEL] Seizure at 1626s: preictal window out of bounds (would start at -174s) — skipping preictal label.
#   Total: 772 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb14
#   [OK] chb14_03.edf  pre=148  int=45
#     [LABEL] Seizure at 1372s: preictal window out of bounds (would start at -428s) — skipping preictal label.
#   [OK] chb14_04.edf  pre=34  int=100
#   [OK] chb14_06.edf  pre=148  int=38
#   [OK] chb14_11.edf  pre=148  int=30
#   [OK] chb14_17.edf  pre=148  int=170
#     [LABEL] Seizure at 1039s: preictal window out of bounds (would start at -761s) — skipping preictal label.
#   [OK] chb14_27.edf  pre=148  int=130
#   Total: 1287 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb15
#     [LABEL] Seizure at 272s: preictal window out of bounds (would start at -1528s) — skipping preictal label.
#     [LABEL] Seizure at 1082s: preictal window out of bounds (would start at -718s) — skipping preictal label.
#     [LABEL] Seizure at 1591s: preictal window out of bounds (would start at -209s) — skipping preictal label.
#   [OK] chb15_17.edf  pre=148  int=39
#     [LABEL] Seizure at 607s: preictal window out of bounds (would start at -1193s) — skipping preictal label.
#     [LABEL] Seizure at 760s: preictal window out of bounds (would start at -1040s) — skipping preictal label.
#     [LABEL] Seizure at 876s: preictal window out of bounds (would start at -924s) — skipping preictal label.
#     [LABEL] Seizure at 1751s: preictal window out of bounds (would start at -49s) — skipping preictal label.
#     [LABEL] Seizure at 834s: preictal window out of bounds (would start at -966s) — skipping preictal label.
#   [OK] chb15_40.edf  pre=24  int=56
#   [OK] chb15_46.edf  pre=148  int=179
#     [LABEL] Seizure at 1108s: preictal window out of bounds (would start at -692s) — skipping preictal label.
#     [LABEL] Seizure at 778s: preictal window out of bounds (would start at -1022s) — skipping preictal label.
#     [LABEL] Seizure at 263s: preictal window out of bounds (would start at -1537s) — skipping preictal label.
#     [LABEL] Seizure at 843s: preictal window out of bounds (would start at -957s) — skipping preictal label.
#     [LABEL] Seizure at 1524s: preictal window out of bounds (would start at -276s) — skipping preictal label.
#     [LABEL] Seizure at 751s: preictal window out of bounds (would start at -1049s) — skipping preictal label.
#   Total: 594 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb16
#   [OK] chb16_10.edf  pre=149  int=77
#     [LABEL] Seizure at 1120s: preictal window out of bounds (would start at -680s) — skipping preictal label.
#   [OK] chb16_14.edf  pre=148  int=32
#     [LABEL] Seizure at 1214s: preictal window out of bounds (would start at -586s) — skipping preictal label.
#     [LABEL] Seizure at 227s: preictal window out of bounds (would start at -1573s) — skipping preictal label.
#     [LABEL] Seizure at 1694s: preictal window out of bounds (would start at -106s) — skipping preictal label.
#     [LABEL] Seizure at 627s: preictal window out of bounds (would start at -1173s) — skipping preictal label.
#   [OK] chb16_18.edf  pre=50  int=9
#   Total: 465 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb17
#   [OK] chb17a_03.edf  pre=148  int=75
#   [OK] chb17a_04.edf  pre=148  int=149
#   [OK] chb17b_63.edf  pre=148  int=160
#   Total: 828 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb18
#   [OK] chb18_29.edf  pre=148  int=194
#     [LABEL] Seizure at 541s: preictal window out of bounds (would start at -1259s) — skipping preictal label.
#   [OK] chb18_31.edf  pre=148  int=55
#   [OK] chb18_32.edf  pre=148  int=37
#   [OK] chb18_35.edf  pre=148  int=66
#     [LABEL] Seizure at 463s: preictal window out of bounds (would start at -1337s) — skipping preictal label.
#   Total: 944 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb19
#     [LABEL] Seizure at 299s: preictal window out of bounds (would start at -1501s) — skipping preictal label.
#   [OK] chb19_29.edf  pre=148  int=143
#   [OK] chb19_30.edf  pre=148  int=162
#   Total: 601 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb20
#     [LABEL] Seizure at 94s: preictal window out of bounds (would start at -1706s) — skipping preictal label.
#     [LABEL] Seizure at 1440s: preictal window out of bounds (would start at -360s) — skipping preictal label.
#   [OK] chb20_13.edf  pre=73  int=68
#   [OK] chb20_14.edf  pre=148  int=44
#     [LABEL] Seizure at 390s: preictal window out of bounds (would start at -1410s) — skipping preictal label.
#     [LABEL] Seizure at 1689s: preictal window out of bounds (would start at -111s) — skipping preictal label.
#   [OK] chb20_16.edf  pre=148  int=69
#     [LABEL] Seizure at 1393s: preictal window out of bounds (would start at -407s) — skipping preictal label.
#   Total: 550 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb22
#   [OK] chb22_20.edf  pre=148  int=183
#   [OK] chb22_25.edf  pre=148  int=160
#     [LABEL] Seizure at 1263s: preictal window out of bounds (would start at -537s) — skipping preictal label.
#   Total: 639 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb23
#   [OK] chb23_06.edf  pre=148  int=402
#     [LABEL] Seizure at 325s: preictal window out of bounds (would start at -1475s) — skipping preictal label.
#   [OK] chb23_08.edf  pre=148  int=510
#   [OK] chb23_09.edf  pre=312  int=470
#   Total: 1990 windows
#
# ───────────────────────────────────────────────────────
# Patient: chb24
#     [LABEL] Seizure at 480s: preictal window out of bounds (would start at -1320s) — skipping preictal label.
#     [LABEL] Seizure at 231s: preictal window out of bounds (would start at -1569s) — skipping preictal label.
#   [OK] chb24_03.edf  pre=51  int=50
#     [LABEL] Seizure at 1088s: preictal window out of bounds (would start at -712s) — skipping preictal label.
#     [LABEL] Seizure at 1411s: preictal window out of bounds (would start at -389s) — skipping preictal label.
#     [LABEL] Seizure at 1745s: preictal window out of bounds (would start at -55s) — skipping preictal label.
#     [LABEL] Seizure at 1229s: preictal window out of bounds (would start at -571s) — skipping preictal label.
#     [LABEL] Seizure at 38s: preictal window out of bounds (would start at -1762s) — skipping preictal label.
#     [LABEL] Seizure at 1745s: preictal window out of bounds (would start at -55s) — skipping preictal label.
#   [OK] chb24_11.edf  pre=148  int=199
#   [OK] chb24_13.edf  pre=148  int=175
#   [OK] chb24_14.edf  pre=148  int=40
#   [OK] chb24_15.edf  pre=148  int=202
#   [OK] chb24_17.edf  pre=148  int=198
#   [OK] chb24_21.edf  pre=148  int=127
#   Total: 1930 windows
#
# Coherence data ready. Patients: 21

# %%
# Cell 3 — CNN (same architecture as main)
class GCDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32).unsqueeze(1)
        self.y = torch.tensor(y, dtype=torch.float32)
    def __len__(self): return len(self.y)
    def __getitem__(self, i): return self.X[i], self.y[i]

class CohCNN(nn.Module):
    def __init__(self, n_ch=18, dropout=0.5):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1,32,3,padding=1), nn.BatchNorm2d(32), nn.ReLU(True),
            nn.Conv2d(32,64,3,padding=1), nn.BatchNorm2d(64), nn.ReLU(True), nn.MaxPool2d(2),
            nn.Conv2d(64,128,3,padding=1), nn.BatchNorm2d(128), nn.ReLU(True), nn.MaxPool2d(2),
        )
        with torch.no_grad():
            flat = self.features(torch.zeros(1,1,n_ch,n_ch)).numel()
        self.classifier = nn.Sequential(
            nn.Flatten(), nn.Dropout(dropout),
            nn.Linear(flat,256), nn.ReLU(True), nn.Dropout(0.3),
            nn.Linear(256,1), nn.Sigmoid()
        )
    def forward(self, x): return self.classifier(self.features(x))

print('CohCNN ready.')
# Out:
# CohCNN ready.

# %%
# Cell 4 — Training utilities
MAX_EPOCHS=50; PATIENCE=10; BATCH_SIZE=64; LR=1e-3; VAL_FRAC=0.15

def train_coh(X_tr, y_tr, X_va, y_va):
    n_pos=max(int((y_tr==1).sum()),1); n_neg=max(int((y_tr==0).sum()),1)
    pw=float(min(n_neg/n_pos,50.0))
    model=CohCNN(N_CHANNELS).to(DEVICE)
    opt=torch.optim.Adam(model.parameters(),lr=LR)
    tr_dl=DataLoader(GCDataset(X_tr,y_tr),batch_size=BATCH_SIZE,shuffle=True)
    va_dl=DataLoader(GCDataset(X_va,y_va),batch_size=BATCH_SIZE)
    best_val,best_wts,p_ctr=float('inf'),None,0
    for epoch in range(1,MAX_EPOCHS+1):
        model.train()
        for xb,yb in tr_dl:
            xb,yb=xb.to(DEVICE),yb.to(DEVICE)
            p=model(xb).squeeze(1)
            loss=-(yb*torch.log(p+1e-8)*pw+(1-yb)*torch.log(1-p+1e-8)).mean()
            opt.zero_grad();loss.backward();opt.step()
        model.eval();va_loss=0.0
        with torch.no_grad():
            for xb,yb in va_dl:
                xb,yb=xb.to(DEVICE),yb.to(DEVICE)
                p=model(xb).squeeze(1)
                va_loss+=(-(yb*torch.log(p+1e-8)*pw+(1-yb)*torch.log(1-p+1e-8)).mean()).item()*len(yb)
        va_loss/=len(va_dl.dataset)
        if epoch%5==0: print(f'  Epoch {epoch}/{MAX_EPOCHS}  val={va_loss:.4f}')
        if va_loss<best_val:
            best_val=va_loss;best_wts={k:v.cpu().clone() for k,v in model.state_dict().items()};p_ctr=0
        else:
            p_ctr+=1
            if p_ctr>=PATIENCE: print(f'  Early stop @{epoch}');break
    model.load_state_dict(best_wts);return model

def predict_coh(model,X):
    model.eval()
    dl=DataLoader(GCDataset(X,np.zeros(len(X))),batch_size=BATCH_SIZE)
    out=[]
    with torch.no_grad():
        for xb,_ in dl: out.append(model(xb.to(DEVICE)).squeeze(1).cpu().numpy())
    return np.concatenate(out)

print('Training utilities ready.')
# Out:
# Training utilities ready.

# %%
# Cell 5 — LOPO
coh_lopo_results={}
n_folds=len(patient_ids)
print('='*60)
print(f'Coherence CNN LOPO  ({n_folds} folds) | device: {DEVICE}')
print('='*60)

for fold_idx,test_pid in enumerate(patient_ids,1):
    print(f'\n[Fold {fold_idx}/{n_folds}]  Test: {test_pid}')
    X_pool=np.concatenate([coh_patient_data[p][0] for p in patient_ids if p!=test_pid])
    y_pool=np.concatenate([coh_patient_data[p][1] for p in patient_ids if p!=test_pid])
    tr_idx,va_idx=train_test_split(np.arange(len(y_pool)),test_size=VAL_FRAC,
                                    random_state=RANDOM_SEED,stratify=y_pool)
    model=train_coh(X_pool[tr_idx],y_pool[tr_idx],X_pool[va_idx],y_pool[va_idx])
    scores=predict_coh(model,coh_patient_data[test_pid][0])
    y_test=coh_patient_data[test_pid][1]
    metrics=evaluate_predictions(y_test,scores,threshold=0.5,patient_id=test_pid)
    coh_lopo_results[test_pid]=metrics
    print(f'  AUC={metrics["auc"]:.3f}  Sens={metrics["sensitivity"]:.3f}  '
          f'Spec={metrics["specificity"]:.3f}  FPR/h={metrics["fpr_per_hour"]:.1f}')

print('\nCoherence LOPO complete.')
# Out:
# ============================================================
# Coherence CNN LOPO  (21 folds) | device: cpu
# ============================================================
#
# [Fold 1/21]  Test: chb01
#   Epoch 5/50  val=0.7295
#   Epoch 10/50  val=0.6506
#   Epoch 15/50  val=0.6294
#   Epoch 20/50  val=0.6276
#   Epoch 25/50  val=0.6571
#   Epoch 30/50  val=0.6383
#   Epoch 35/50  val=0.6158
#   Epoch 40/50  val=0.6793
#   Early stop @43
#   AUC=0.315  Sens=0.402  Spec=0.307  FPR/h=249.4
#
# [Fold 2/21]  Test: chb02
#   Epoch 5/50  val=0.7216
#   Epoch 10/50  val=0.6626
#   Epoch 15/50  val=0.6390
#   Epoch 20/50  val=0.6504
#   Epoch 25/50  val=0.6463
#   Epoch 30/50  val=0.6626
#   Early stop @33
#   AUC=0.342  Sens=0.199  Spec=0.590  FPR/h=147.5
#
# [Fold 3/21]  Test: chb03
#   Epoch 5/50  val=0.7550
#   Epoch 10/50  val=0.6744
#   Epoch 15/50  val=0.7304
#   Epoch 20/50  val=0.6403
#   Epoch 25/50  val=0.6397
#   Epoch 30/50  val=0.6217
#   Epoch 35/50  val=0.6725
#   Early stop @36
#   AUC=0.525  Sens=0.624  Spec=0.397  FPR/h=217.0
#
# [Fold 4/21]  Test: chb04
#   Epoch 5/50  val=0.8953
#   Epoch 10/50  val=0.8953
#   Epoch 15/50  val=0.8953
#   Epoch 20/50  val=0.8953
#   Early stop @20
#   AUC=0.500  Sens=1.000  Spec=0.000  FPR/h=360.0
#
# [Fold 5/21]  Test: chb05
#   Epoch 5/50  val=0.7265
#   Epoch 10/50  val=0.7116
#   Epoch 15/50  val=0.6430
#   Epoch 20/50  val=0.6338
#   Epoch 25/50  val=0.6347
#   Epoch 30/50  val=0.6207
#   Early stop @33
#   AUC=0.539  Sens=0.511  Spec=0.546  FPR/h=163.5
#
# [Fold 6/21]  Test: chb06
#   Epoch 5/50  val=0.6700
#   Epoch 10/50  val=0.6129
#   Epoch 15/50  val=0.5856
#   Epoch 20/50  val=0.5666
#   Epoch 25/50  val=0.5934
#   Epoch 30/50  val=0.5949
#   Epoch 35/50  val=0.6414
#   Early stop @36
#   AUC=0.516  Sens=0.588  Spec=0.450  FPR/h=198.0
#
# [Fold 7/21]  Test: chb07
#   Epoch 5/50  val=0.6986
#   Epoch 10/50  val=0.6406
#   Epoch 15/50  val=0.5993
#   Epoch 20/50  val=0.5805
#   Epoch 25/50  val=0.6143
#   Epoch 30/50  val=0.5932
#   Early stop @34
#   AUC=0.338  Sens=0.384  Spec=0.365  FPR/h=228.6
#
# [Fold 8/21]  Test: chb08
#   Epoch 5/50  val=0.7652
#   Epoch 10/50  val=0.6812
#   Epoch 15/50  val=0.6415
#   Epoch 20/50  val=0.6584
#   Epoch 25/50  val=0.6352
#   Epoch 30/50  val=0.6553
#   Epoch 35/50  val=0.7400
#   Early stop @35
#   AUC=0.539  Sens=0.881  Spec=0.228  FPR/h=277.9
#
# [Fold 9/21]  Test: chb09
#   Epoch 5/50  val=0.6992
#   Epoch 10/50  val=0.6388
#   Epoch 15/50  val=0.6223
#   Epoch 20/50  val=0.6065
#   Epoch 25/50  val=0.6403
#   Epoch 30/50  val=0.6709
#   Early stop @30
#   AUC=0.541  Sens=0.512  Spec=0.535  FPR/h=167.3
#
# [Fold 10/21]  Test: chb10
#   Epoch 5/50  val=0.6927
#   Epoch 10/50  val=0.6485
#   Epoch 15/50  val=0.6469
#   Epoch 20/50  val=0.6266
#   Epoch 25/50  val=0.7030
#   Early stop @26
#   AUC=0.521  Sens=0.633  Spec=0.380  FPR/h=223.3
#
# [Fold 11/21]  Test: chb13
#   Epoch 5/50  val=0.7085
#   Epoch 10/50  val=0.6544
#   Epoch 15/50  val=0.6480
#   Epoch 20/50  val=0.6328
#   Epoch 25/50  val=0.6541
#   Epoch 30/50  val=0.6955
#   Epoch 35/50  val=0.6361
#   Early stop @36
#   AUC=0.518  Sens=0.802  Spec=0.220  FPR/h=281.0
#
# [Fold 12/21]  Test: chb14
#   Epoch 5/50  val=0.7139
#   Epoch 10/50  val=0.6650
#   Epoch 15/50  val=0.6404
#   Epoch 20/50  val=0.6182
#   Epoch 25/50  val=0.6256
#   Epoch 30/50  val=0.6233
#   Epoch 35/50  val=0.6270
#   Early stop @39
#   AUC=0.533  Sens=0.185  Spec=0.838  FPR/h=58.2
#
# [Fold 13/21]  Test: chb15
#   Epoch 5/50  val=0.7501
#   Epoch 10/50  val=0.6893
#   Epoch 15/50  val=0.6683
#   Epoch 20/50  val=0.6128
#   Epoch 25/50  val=0.6306
#   Epoch 30/50  val=0.6372
#   Epoch 35/50  val=0.6363
#   Early stop @38
#   AUC=0.594  Sens=0.475  Spec=0.657  FPR/h=123.5
#
# [Fold 14/21]  Test: chb16
#   Epoch 5/50  val=0.7161
#   Epoch 10/50  val=0.6517
#   Epoch 15/50  val=0.6276
#   Epoch 20/50  val=0.6195
#   Epoch 25/50  val=0.6312
#   Epoch 30/50  val=0.5838
#   Epoch 35/50  val=0.6223
#   Epoch 40/50  val=0.6050
#   Early stop @40
#   AUC=0.486  Sens=0.444  Spec=0.551  FPR/h=161.7
#
# [Fold 15/21]  Test: chb17
#   Epoch 5/50  val=0.7139
#   Epoch 10/50  val=0.6730
#   Epoch 15/50  val=0.6484
#   Epoch 20/50  val=0.6177
#   Epoch 25/50  val=0.6692
#   Early stop @28
#   AUC=0.566  Sens=0.581  Spec=0.529  FPR/h=169.7
#
# [Fold 16/21]  Test: chb18
#   Epoch 5/50  val=0.7231
#   Epoch 10/50  val=0.6608
#   Epoch 15/50  val=0.6294
#   Epoch 20/50  val=0.6213
#   Epoch 25/50  val=0.6412
#   Epoch 30/50  val=0.6375
#   Early stop @30
#   AUC=0.521  Sens=0.220  Spec=0.824  FPR/h=63.4
#
# [Fold 17/21]  Test: chb19
#   Epoch 5/50  val=0.7283
#   Epoch 10/50  val=0.6605
#   Epoch 15/50  val=0.6602
#   Epoch 20/50  val=0.6371
#   Epoch 25/50  val=0.6489
#   Early stop @28
#   AUC=0.550  Sens=0.784  Spec=0.210  FPR/h=284.5
#
# [Fold 18/21]  Test: chb20
#   Epoch 5/50  val=0.7023
#   Epoch 10/50  val=0.6662
#   Epoch 15/50  val=0.6166
#   Epoch 20/50  val=0.6246
#   Epoch 25/50  val=0.6328
#   Early stop @29
#   AUC=0.481  Sens=0.466  Spec=0.536  FPR/h=167.1
#
# [Fold 19/21]  Test: chb22
#   Epoch 5/50  val=0.7244
#   Epoch 10/50  val=0.6628
#   Epoch 15/50  val=0.6341
#   Epoch 20/50  val=0.6337
#   Epoch 25/50  val=0.6480
#   Epoch 30/50  val=0.6580
#   Early stop @34
#   AUC=0.469  Sens=0.591  Spec=0.367  FPR/h=227.8
#
# [Fold 20/21]  Test: chb23
#   Epoch 5/50  val=0.7330
#   Epoch 10/50  val=0.6498
#   Epoch 15/50  val=0.6447
#   Epoch 20/50  val=0.6598
#   Epoch 25/50  val=0.6217
#   Early stop @26
#   AUC=0.485  Sens=0.599  Spec=0.374  FPR/h=225.3
#
# [Fold 21/21]  Test: chb24
#   Epoch 5/50  val=0.7723
#   Epoch 10/50  val=0.7008
#   Epoch 15/50  val=0.6413
#   Epoch 20/50  val=0.6829
#   Epoch 25/50  val=0.6759
#   Epoch 30/50  val=0.6497
#   Epoch 35/50  val=0.6693
#   Early stop @37
#   AUC=0.496  Sens=0.475  Spec=0.510  FPR/h=176.5
#
# Coherence LOPO complete.

# %%
# Cell 6 — Save & plot
METRIC_KEYS = ['auc', 'auc_pr', 'sensitivity', 'specificity', 'f1', 'balanced_accuracy', 'fpr_per_hour']

rows=[{'patient':pid,**{k:coh_lopo_results[pid][k] for k in METRIC_KEYS}} for pid in patient_ids]
coh_df=pd.DataFrame(rows)
coh_df=pd.concat([coh_df,
    pd.DataFrame([{'patient':'MEAN',**{k:round(coh_df[k].mean(),4) for k in METRIC_KEYS}}]),
    pd.DataFrame([{'patient':'STD', **{k:round(coh_df[k].std(), 4) for k in METRIC_KEYS}}])
],ignore_index=True)
print('=== Coherence CNN LOPO ===')
print(coh_df.to_string(index=False,float_format='{:.3f}'.format))
os.makedirs(RESULTS_DIR,exist_ok=True)
coh_df.to_csv(os.path.join(RESULTS_DIR,'lopo_coherence.csv'),index=False)

gc_csv=os.path.join(RESULTS_DIR,'lopo_results.csv')
if os.path.exists(gc_csv):
    gc_df=pd.read_csv(gc_csv)
    pid_col=[c for c in gc_df.columns if 'patient' in c.lower()][0]
    gc_df=gc_df.rename(columns={pid_col:'patient'})
    gc_df=gc_df[~gc_df['patient'].isin(['MEAN','STD'])].reset_index(drop=True)
    coh_df2=coh_df[~coh_df['patient'].isin(['MEAN','STD'])].reset_index(drop=True)
    auc_col='auc' if 'auc' in gc_df.columns else gc_df.columns[1]
    x=np.arange(len(patient_ids))
    fig,ax=plt.subplots(figsize=(12,5))
    ax.bar(x-0.2,gc_df[auc_col].values,  0.4,label='GC-CNN (time-domain)',  color='steelblue',alpha=0.8)
    ax.bar(x+0.2,coh_df2['auc'].values,  0.4,label='Coherence (freq-domain)',color='mediumpurple',alpha=0.8)
    ax.axhline(gc_df[auc_col].mean(),  color='steelblue',linestyle='--',lw=1)
    ax.axhline(coh_df2['auc'].mean(),  color='mediumpurple',linestyle='--',lw=1)
    ax.set_xticks(x);ax.set_xticklabels(patient_ids,rotation=45,ha='right',fontsize=7)
    ax.set_title('GC-CNN vs Coherence CNN — AUC-ROC per Patient',fontsize=12,fontweight='bold')
    ax.legend(fontsize=9);plt.tight_layout()
    plt.savefig(os.path.join(RESULTS_DIR,'comparison_gc_vs_coherence.png'),dpi=150,bbox_inches='tight')
    plt.show()
print('Done.')
# Out:
# === Coherence CNN LOPO ===
# patient   auc  auc_pr  sensitivity  specificity    f1  balanced_accuracy  fpr_per_hour
#   chb01 0.315   0.508        0.402        0.307 0.442              0.355       249.386
#   chb02 0.342   0.378        0.199        0.590 0.241              0.395       147.523
#   chb03 0.525   0.707        0.624        0.397 0.652              0.510       217.009
#   chb04 0.500   0.147        1.000        0.000 0.256              0.500       360.000
#   chb05 0.539   0.677        0.511        0.546 0.578              0.528       163.506
#   chb06 0.516   0.161        0.588        0.450 0.264              0.519       197.987
#   chb07 0.338   0.107        0.384        0.365 0.156              0.375       228.617
#   chb08 0.539   0.614        0.881        0.228 0.723              0.555       277.906
#   chb09 0.541   0.228        0.512        0.535 0.314              0.523       167.333
#   chb10 0.521   0.281        0.633        0.380 0.372              0.506       223.257
#   chb13 0.518   0.567        0.802        0.220 0.674              0.511       280.976
#   chb14 0.533   0.626        0.185        0.838 0.286              0.511        58.246
#   chb15 0.594   0.587        0.475        0.657 0.537              0.566       123.504
#   chb16 0.486   0.744        0.444        0.551 0.556              0.497       161.695
#   chb17 0.566   0.601        0.581        0.529 0.584              0.555       169.688
#   chb18 0.521   0.652        0.220        0.824 0.332              0.522        63.409
#   chb19 0.550   0.567        0.784        0.210 0.603              0.497       284.459
#   chb20 0.481   0.664        0.466        0.536 0.550              0.501       167.072
#   chb22 0.469   0.445        0.591        0.367 0.509              0.479       227.755
#   chb23 0.485   0.291        0.599        0.374 0.396              0.486       225.326
#   chb24 0.496   0.486        0.475        0.510 0.477              0.492       176.549
#    MEAN 0.494   0.478        0.541        0.448 0.453              0.494       198.629
#     STD 0.074   0.201        0.211        0.201 0.162              0.055        72.319
# Done.
